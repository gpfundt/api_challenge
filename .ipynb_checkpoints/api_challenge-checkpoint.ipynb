# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)


# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    places = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if places not in cities:
        cities.append(places)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 617

# %%
# Perform a weather check on each city using a series of successive API calls.
# Include a print log of each city as it'sbeing processed (with the city number and city name)

df=pd.DataFrame()
df['City'] = ''
df['Country'] = ''
df['Lat'] = ''
df['Lng'] = ''
df['Humidity'] = ''
df['Cloudiness'] = ''
df['Max Temp'] = ''
df['Wind Speed'] = ''
df['Date'] = ''

for city in cities:
    real_city = city.title()
    url = f'http://api.openweathermap.org/data/2.5/weather?q={real_city}&appid={api_key}'
    data = requests.get(url).json()
    try:
        lat = data["coord"]["lat"]
        lon = data["coord"]["lon"]
        country = data['sys']['country']
        humidity = data['main']['humidity']
        cloudiness = data['clouds']['all']
        max_temp = data['main']['temp_max']
        wind_speed = data['wind']['speed']
        date = data['dt']
        df.loc[city,'City'] = real_city
        df.loc[city,'Country'] = country
        df.loc[city,'Lat'] = lat
        df.loc[city,'Lng'] = lon
        df.loc[city,'Humidity'] = humidity
        df.loc[city,'Cloudiness'] = cloudiness
        df.loc[city,'Max Temp'] = max_temp
        df.loc[city,'Wind Speed'] = wind_speed
        df.loc[city,'Date'] = date
    except KeyError:
        print(f'City {real_city} not found. Skipping...')
# Out:
# City Lolua not found. Skipping...
# City Belushya Guba not found. Skipping...
# City Grand Centre not found. Skipping...
# City Tsihombe not found. Skipping...
# City Maghama not found. Skipping...
# City Bengkulu not found. Skipping...
# City Taolanaro not found. Skipping...
# City Nizhneyansk not found. Skipping...
# City Saryshagan not found. Skipping...
# City Illoqqortoormiut not found. Skipping...
# City Grand River South East not found. Skipping...
# City Amderma not found. Skipping...
# City Korla not found. Skipping...
# City Kamenskoye not found. Skipping...
# City Linchuan not found. Skipping...
# City Vaitupu not found. Skipping...
# City Maneadero not found. Skipping...
# City Sentyabrskiy not found. Skipping...
# City Satitoa not found. Skipping...
# City Olafsvik not found. Skipping...
# City Samusu not found. Skipping...
# City Stornoway not found. Skipping...
# City Doctor Pedro P. Pena not found. Skipping...
# City Saleaula not found. Skipping...
# City Attawapiskat not found. Skipping...
# City Yunjinghong not found. Skipping...
# City Mafinga not found. Skipping...
# City Artyk not found. Skipping...
# City Formoso Do Araguaia not found. Skipping...
# City Karaul not found. Skipping...
# City Mys Shmidta not found. Skipping...
# City Barentsburg not found. Skipping...
# City Sorvag not found. Skipping...
# City Burica not found. Skipping...
# City Umm Jarr not found. Skipping...
# City Rawannawi not found. Skipping...
# City Kashi not found. Skipping...
# City Santa Eulalia Del Rio not found. Skipping...
# City Rolim De Moura not found. Skipping...
# City Tartus not found. Skipping...
# City Mme not found. Skipping...
# City Marcona not found. Skipping...
# City Paradwip not found. Skipping...
# City Skagastrond not found. Skipping...
# City Auala not found. Skipping...
# City Cazaje not found. Skipping...
# City Umzimvubu not found. Skipping...
# City Asau not found. Skipping...
# City Palabuhanratu not found. Skipping...
# City Krasnoselkup not found. Skipping...
# City Fevralsk not found. Skipping...
# City Bolungarvik not found. Skipping...
# City Tidore not found. Skipping...
# City Zachagansk not found. Skipping...
# City Bairiki not found. Skipping...
# City Hvolsvollur not found. Skipping...
# City Sayabec not found. Skipping...
# City Vedaranniyam not found. Skipping...
# City Kobojango not found. Skipping...
# City Sao Felipe not found. Skipping...
# City Louisbourg not found. Skipping...

# %%
df.to_csv('weather_data.csv')
df.reset_index(inplace = True)
df.head()
# Out:
#          index         City Country    Lat    Lng Humidity Cloudiness  \
# 0   castrillon   Castrillon      ES   43.4  -6.79      100         90
# 1   bredasdorp   Bredasdorp      ZA -34.53  20.04       77         29
# 2       dikson       Dikson      RU  73.51  80.55       99        100
# 3  port alfred  Port Alfred      ZA -33.59  26.89       88          4
# 4    sinnamary    Sinnamary      GF   5.38 -52.96       82        100
#
#   Max Temp Wind Speed        Date
# 0   288.15        2.1  1571007561
# 1   289.82        5.1  1571007032
# 2   272.68      3.443  1571007053
# 3   289.82       0.89  1571007057
# 4   300.67      7.343  1571007561

# %%
xaxis = df['Lat']
yaxist = df['Max Temp']
yaxish = df['Humidity']
yaxisc = df['Cloudiness']
yaxisw = df['Wind Speed']

# %%
plt.scatter(xaxis, yaxist)
plt.grid()
plt.title('Latitude vs Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('temp_comparison.png')

# %%
plt.scatter(xaxis, yaxish)
plt.grid()
plt.title('Latitude vs Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('humidity_comparison.png')

# %%
plt.scatter(xaxis, yaxisc)
plt.grid()
plt.title('Latitude vs Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('cloud_comparison.png')

# %%
plt.scatter(xaxis, yaxisw)
plt.grid()
plt.title('Latitude vs Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('wind_comparison.png')

# %%
#OBSERVATIONS
# At latitudes closer to 0 (closer to the equator) the temperature is more frequently higher.
# Cloudiness is not significantly effected by latitude.
# Windspeed is not significantly effected by latitude.

# %%
#TEST FOR API ON LONDON ONLY

# fdf = pd.DataFrame()
# fdf['City'] = ''
# fdf['Country'] = ''
# fdf['Lat'] = ''
# fdf['Lng'] = ''
# fdf['Humidity'] = ''
# fdf['Cloudiness'] = ''
# fdf['Max Temp'] = ''
# fdf['Wind Speed'] = ''

# url = f'http://api.openweathermap.org/data/2.5/weather?q=London&appid={api_key}'
# data = requests.get(url).json()
# print(json.dumps(data))
# lat = data["coord"]["lat"]
# lon = data["coord"]["lon"]
# humidity = data['main']['humidity']
# cloudiness = data['clouds']['all']
# country = data['sys']['country']
# max_temp = data['main']['temp_max']
# wind_speed = data['wind']['speed']

# fdf.loc[0,'City'] = 'London'
# fdf.loc[0,'Country'] = country
# fdf.loc[0,'Lat'] = lat
# fdf.loc[0,'Lng'] = lon
# fdf.loc[0,'Humidity'] = humidity
# fdf.loc[0,'Cloudiness'] = cloudiness
# fdf.loc[0,'Max Temp'] = max_temp
# fdf.loc[0,'Wind Speed'] = wind_speed


# fdf.head()

# %%
#OBSERVATIONS
# At latitudes closer to 0 (closer to the equator) the temperature is more frequently higher.
# Cloudiness is not effected by latitude.
# Windspeed is not effected by latitude.
